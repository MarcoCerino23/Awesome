# %% [markdown]
# ## Import libraries

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    from google.colab import drive

    drive.mount('/gdrive')
    # %cd /gdrive/My Drive/[2024-2025] AN2DL/Homework 1
    # !pip install keras_cv
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1M1TW6PTeAUJgqEz6TK_sPPBirCoPACP_/Homework 1
# Requirement already satisfied: keras_cv in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras_cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras_cv) (4.9.7)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (1.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)

# %% [markdown]
# ## Import preprocessed data

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import requests
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import keras_cv

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %% [markdown]
# ### Utils functions

# %%
from datetime import datetime, timedelta
def time():
    if IN_COLAB:
        return datetime.now() + timedelta(hours=1)
    else:
        return datetime.now()

# Function to stringify the layer configurations
def stringify_augmentation(augmentation_pipeline):
    layer_descriptions = []
    for layer in augmentation_pipeline.layers:
        layer_name = layer.__class__.__name__
        # Filter out only essential parameters
        essential_params = {k: v for k, v in layer.get_config().items() if k in ["mode", "height_factor", "width_factor", "factor", "fill_mode", "interpolation"]}
        layer_desc = f"{layer_name}(" + ", ".join(f"{k}={v}" for k, v in essential_params.items()) + ")"
        layer_descriptions.append(layer_desc)
    return "[" + ", ".join(layer_descriptions) + "]"

# %%
X, y = np.load('Preprocessed_data/X.npy'), np.load('Preprocessed_data/y.npy')
# convert y to 1D array
y = y.squeeze()

class_names = np.load('Preprocessed_data/class_names.npy')
print(X.shape, y.shape)
print(class_names)
# Out:
# (11959, 96, 96, 3) (11959,)
# ['class_0' 'class_1' 'class_2' 'class_3' 'class_4' 'class_5' 'class_6'
#  'class_7']

# %% [markdown]
# ### Plot distribution of classes

# %%
def plot_class_distribution(y_train, class_names):
    # Set seaborn style for the plot
    sns.set_style("whitegrid")
    plt.figure(figsize=(18, 6))

    # Calculate class distributions for training and test sets
    train_dist = np.bincount(y_train)


    # Create x positions and set bar width
    x = np.arange(len(class_names))
    width = 0.35

    # Plot bars for training and test distributions
    plt.bar(x - width / 2, train_dist, width, label='Training', color='#2ecc71', alpha=0.7)

    # Customise plot title and labels
    plt.title('Class Distribution', pad=20, fontsize=14)
    plt.xlabel('Classes')
    plt.ylabel('Number of Images')

    # Set class names as x-axis labels with rotation
    plt.xticks(x, class_names, rotation=45, ha='right')

    # Add legend for training and test distributions
    plt.legend(loc='lower right')

    # Adjust layout for optimal spacing
    plt.tight_layout()
    plt.show()

# Execute function to plot class distribution
plot_class_distribution(y, class_names)

# %% [markdown]
# ## Generate validation split(s)

# %%
# Split validation set into validation and test sets with stratification
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=0.2, stratify=y)

# Convert class labels to categorical format for training, validation, and test sets
y_train = tfk.utils.to_categorical(y_train, num_classes=len(class_names))
y_val = tfk.utils.to_categorical(y_val, num_classes=len(class_names))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (9567, 96, 96, 3), y_train shape: (9567, 8)
# X_val shape: (2392, 96, 96, 3), y_val shape: (2392, 8)

# %% [markdown]
# ## Optionally use Weighted loss
# we can avoid setting this parameter in the training function if we don't want to weight the loss

# %%
class_counts = np.bincount(np.argmax(y_train, axis=1))  # Conta le occorrenze per ogni classe
total_samples = len(y_train)

# Calcola i pesi delle classi come frequenza inversa
class_weights = {i: total_samples / (len(class_counts) * count) for i, count in enumerate(class_counts)}
print("Class weights:", class_weights)
# Out:
# Class weights: {0: 1.753482404692082, 1: 0.6853151862464183, 2: 1.3777361751152073, 3: 0.7377390499691548, 4: 1.7612297496318114, 5: 1.506139798488665, 6: 0.6415638412017167, 7: 0.9101027397260274}

# %% [markdown]
# ## Define a Model

# %%
# Set some variables for convenience to refer to the chosen architecture

NET_NAME = 'EfficientNetV2M'
# (OPTIONAL) this will be added to the model name to identify the run in the folder, logs...
IDENTIFIER = ""
MODEL_NAME = NET_NAME + ("_" + IDENTIFIER if IDENTIFIER else "")

# this will be added as a file in the model folder to describe the run
RUN_DESCRIPTION = "abbiamo scelto efficientnetb4 come modello, abbiamo fatto questa scelta per questo motivo ecc ecc"

# Set the hyperparameters (this metrics will be saved with the weights)
# These refers specifically to the first run (transfer learning)
hyperparameters = {
    'batch_size': 128,
    'epochs': 200,
    'lr': 0.001,
    'weight_decay': 0.001,#0.001,
    'patience': 10,
    'optimizer': 'adam', # to change manually from here if needed
    'weighted_loss': True,
    'label_smoothing': 0.1, # set None to deactivate
    'mixup': False,
    'mixup_alpha': 0.2,
    'mixup_prob': 0.5,
    'transfer_learning': 'full'
}

# %% [markdown]
# ### Select a pretrained network from keras.application and optionally display it (showing number of layers, parameters etc)

# %%
# Initialise chosen model with pretrained weights, for transfer learning
net = tfk.applications.EfficientNetV2M(
    input_shape=(96, 96, 3),
    include_top=False,
    weights='imagenet',#mettere image net, prima era none
    pooling='avg'
)

# Display a summary of the model architecture
#net.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
#tfk.utils.plot_model(net, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ### Choose augmentation layer

# %%
import keras_cv
# Apply data augmentation for training robustness
"""
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal"),
    tfkl.RandomTranslation(0.3, 0.3),
    tfkl.RandomRotation(0.5),
    tfkl.RandomZoom(0.4),
    tfkl.RandomContrast(0.7),
    tfkl.RandomBrightness(0.4),
    keras_cv.layers.RandomSharpness(factor=(0.3, 0.8), value_range=(0, 255)),
    tfkl.GaussianNoise(stddev=0.1),
    #keras_cv.layers.RandomChannelShift(value_range=(0, 255), factor=0.05, channels=3),
    #keras_cv.layers.RandomColorDegeneration(factor=0.1),
    keras_cv.layers.RandomSaturation(factor=0.05),
    #keras_cv.layers.RandomHue(factor=0.05, value_range=(0, 255)),
    keras_cv.layers.RandomContrast(factor=0.05, value_range=(0, 255)),
    #keras_cv.layers.Solarization(value_range=(0, 255), addition_factor=0.0, threshold_factor=0.2)

], name='preprocessing')
"""

AUTO = tf.data.AUTOTUNE
BATCH_SIZE = 128

IMAGE_SIZE = 96
"""
layers = keras_cv.layers.RandAugment(
    value_range=(0, 255), augmentations_per_image=3, magnitude=0.5
)
"""
def to_dict(image, label):
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)
    return {"images": image, "labels": label}

layers = keras_cv.layers.RandAugment.get_standard_policy(
    value_range=(0, 255), magnitude=0.3, magnitude_stddev=0.3#era 0.3
)

layers = layers + [keras_cv.layers.GridMask()]

random_pipeline = keras_cv.layers.RandomAugmentationPipeline(
    layers=layers, augmentations_per_image=3
)
cut_mix = keras_cv.layers.CutMix()
mix_up = keras_cv.layers.MixUp(alpha=0.1)#era 0.2

def cutmix_and_mixup(X, y):
  # we must convert to a dictionary to apply these transfromations
  X = to_dict(X, y)
  #X = cut_mix(X)
  X = mix_up(X)
  return X['images'], X['labels']

train_ds_rand = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(BATCH_SIZE * 100)
    .batch(BATCH_SIZE)
    .map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    )
    .map(
        lambda x, y: (random_pipeline(tf.cast(x, tf.uint8)), y),
        num_parallel_calls=AUTO,
    )
    .map(
        lambda x, y: (cutmix_and_mixup(x, y)),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(BATCH_SIZE)
    .map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)




# Visualize examples of augmented images
def visualize_augmented_images(image, augmentation):
    # plot original image together with other 8 versions of the same image, in the same plot
    fig, ax = plt.subplots(3, 3, figsize=(20, 20))
    ax = ax.ravel()
    ax[0].imshow(np.array(image, dtype='uint8'))
    ax[0].set_title('Original image')
    ax[0].axis('off')
    for i in range(1, 9):
        augmented_image = augmentation(tf.expand_dims(image, 0))

        ax[i].imshow(np.array(augmented_image[0], dtype='uint8'))
        ax[i].set_title(f'Augmented image {i}')
        ax[i].axis('off')



"""# Load some example image stratified by class
indexes = [np.where(np.argmax(y_train, axis=1) == i)[0][0] for i in range(len(class_names))]
indexes = np.random.choice(indexes, 3)
example_images = X_train[indexes]
# Visualize augmented images
for i in range(len(indexes)):
    visualize_augmented_images(example_images[i], augmentation)"""
# Out:
# '# Load some example image stratified by class\nindexes = [np.where(np.argmax(y_train, axis=1) == i)[0][0] for i in range(len(class_names))]\nindexes = np.random.choice(indexes, 3)\nexample_images = X_train[indexes]\n# Visualize augmented images\nfor i in range(len(indexes)):\n    visualize_augmented_images(example_images[i], augmentation)'

# %% [markdown]
# ### Add mixup images generator to include mixed up images (not a layer, but a preprocessing at batch generator level)

# %%
from tensorflow.keras.utils import Sequence

# Converti le etichette in float32 per essere compatibili con MixUp
y_train = tf.cast(y_train, dtype=tf.float32)
y_val = tf.cast(y_val, dtype=tf.float32)

# Generatore di dati personalizzato con MixUp applicato parzialmente
class PartialMixupDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size=64, mixup_alpha=0.2, mixup_prob=0.5, shuffle=True):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.mixup = keras_cv.layers.MixUp(alpha=mixup_alpha)
        self.mixup_prob = mixup_prob  # Probabilità di applicare MixUp
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        # Estrai un batch di indici
        batch_indices = tf.constant(self.indices[index * self.batch_size:(index + 1) * self.batch_size])
        batch_images = tf.gather(self.images, batch_indices)
        batch_labels = tf.gather(self.labels, batch_indices)

        # Applica MixUp solo con una certa probabilità
        if np.random.rand() < self.mixup_prob:
            mixed_data = self.mixup({'images': batch_images, 'labels': batch_labels})
            batch_images, batch_labels = mixed_data['images'], mixed_data['labels']

        return batch_images, batch_labels  # Ritorna batch mixato/non-mixato

    def on_epoch_end(self):
        # Mescola i dati a fine epoca se shuffle è True
        self.indices = np.arange(len(self.images))
        if self.shuffle:
            np.random.shuffle(self.indices)

if hyperparameters['mixup']:
    # Crea un'istanza del generatore di dati
    train_generator = PartialMixupDataGenerator(
        images=X_train,
        labels=y_train,
        batch_size=hyperparameters['batch_size'],
        mixup_alpha=hyperparameters['mixup_alpha'],
        mixup_prob=hyperparameters['mixup_prob']
    )

# %% [markdown]
# ### Fully visualize the crap we are feeding into the network

# %%
# Visualize some example of a batch with MixUp applied, and also augmented
if hyperparameters['mixup']:
    # Estrai un batch di immagini e etichette
    batch_images, batch_labels = train_generator[8]
    # Visualizza le immagini del batch
    for i in range(len(batch_images[:3])):
        visualize_augmented_images(batch_images[i], augmentation)
else:
    sample_images, _ = next(iter(train_ds_rand))
    plt.figure(figsize=(10, 10))
    for i, image in enumerate(sample_images[:9]):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(image.numpy().astype("int"))
      plt.axis("off")

# %% [markdown]
# OPTIMIZER

# %%
# Early stopping helps as it stops training if val_loss(validation score) does not decrease.
"""
# !pip install tensorflow_addons
import tensorflow_addons as tfa


lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=100, decay_rate=0.96,
    staircase=True)


def Ranger(sync_period=6,
           slow_step_size=0.5,
           learning_rate=0.001,
           beta_1=0.9,
           beta_2=0.999,
           epsilon=1e-7,
           weight_decay=0.,
           amsgrad=False,
           sma_threshold=5.0,
           total_steps=0,
           warmup_proportion=0.1,
           min_lr=0.,
           name="Ranger"):
    inner = tfa.optimizers.RectifiedAdam(learning_rate, beta_1, beta_2, epsilon, weight_decay, amsgrad, sma_threshold, total_steps, warmup_proportion, min_lr, name)
    optim = tfa.optimizers.Lookahead(inner, sync_period, slow_step_size, name)
    return optim
"""
# Out:
# '\n!pip install tensorflow_addons\nimport tensorflow_addons as tfa\n\n\nlr_schedule = ExponentialDecay(\n    initial_learning_rate=1e-3,\n    decay_steps=100, decay_rate=0.96,\n    staircase=True)\n\n\ndef Ranger(sync_period=6,\n           slow_step_size=0.5,\n           learning_rate=0.001,\n           beta_1=0.9,\n           beta_2=0.999,\n           epsilon=1e-7,\n           weight_decay=0.,\n           amsgrad=False,\n           sma_threshold=5.0,\n           total_steps=0,\n           warmup_proportion=0.1,\n           min_lr=0.,\n           name="Ranger"):\n    inner = tfa.optimizers.RectifiedAdam(learning_rate, beta_1, beta_2, epsilon, weight_decay, amsgrad, sma_threshold, total_steps, warmup_proportion, min_lr, name)\n    optim = tfa.optimizers.Lookahead(inner, sync_period, slow_step_size, name)\n    return optim\n'

# %%
from tensorflow.keras.optimizers import Lion
from tensorflow.keras.optimizers.schedules import ExponentialDecay

lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=100, decay_rate=0.96,
    staircase=True)

optimizer = Lion(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=1e-2,
    use_ema=False  # Setta True se vuoi usare EMA, ma normalmente è disattivato per Lion
)

# %% [markdown]
# ### Add preprocessing and augmentation layers to the initial stage of the model ("in front" of the selected network)

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input



# Freeze all layers in net to use it solely as a feature extractor
net.trainable = False

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

#x = preprocess_input(inputs)
x = tfkl.GaussianNoise(stddev=0.1)(inputs)
#x = augmentation(x)
#x = augmentation(inputs)
x = net(x)
# Pass augmented inputs through the network feature extractor
#x = net(x)
#x = tfkl.Dense(256, activation='relu', name='dense_1')(x)

# Add normalization layer

#see if it's necessary to add a dense layer, in general is added in this part
#x = tfkl.Dense(256, activation='relu')(x)
x = tfkl.BatchNormalization(name='batch_norm_1')(x)
# Add a dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout')(x)




# Add final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', dtype='float32', name='output')(x)

# Define the complete model linking input and output
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(label_smoothing=hyperparameters['label_smoothing']), optimizer=tfk.optimizers.Adam(hyperparameters["lr"], weight_decay=hyperparameters['weight_decay']), metrics=['accuracy'])#optimizer=tfk.optimizers.Adam(hyperparameters["lr"], weight_decay=hyperparameters['weight_decay'])

# Display a summary of the model architecture
#tl_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
#tfk.utils.plot_model(tl_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### First we use transfer learning

# %%
# Train the model
tl_history = tl_model.fit(
    train_ds_rand,
    batch_size=(hyperparameters['batch_size'] if not hyperparameters['mixup'] else None),
    epochs=hyperparameters['epochs'],
    validation_data=val_ds,
    class_weight=(class_weights if hyperparameters['weighted_loss'] else None),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=hyperparameters['patience'], restore_best_weights=True)]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
run_dir_name = MODEL_NAME + "_" + str(final_val_accuracy) + "__" + time().strftime("_%Y-%m-%d_%H.%M")
model_filename = 'weights.keras'
os.makedirs("weights/transfer_learning/"+ run_dir_name, exist_ok=True)
model_filepath = "weights/transfer_learning/"+ run_dir_name + "/" + model_filename
tl_model.save(model_filepath)

# Free memory by deleting the model instance
del tl_model
# Out:
# Epoch 1/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 135s 963ms/step - accuracy: 0.3570 - loss: 2.1270 - val_accuracy: 0.7191 - val_loss: 1.3377
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 314ms/step - accuracy: 0.5179 - loss: 1.6209 - val_accuracy: 0.8031 - val_loss: 1.1020
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 323ms/step - accuracy: 0.5638 - loss: 1.5080 - val_accuracy: 0.8717 - val_loss: 0.9216
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 313ms/step - accuracy: 0.5901 - loss: 1.4206 - val_accuracy: 0.8721 - val_loss: 0.8563
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 315ms/step - accuracy: 0.6143 - loss: 1.4241 - val_accuracy: 0.8771 - val_loss: 0.8346
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 316ms/step - accuracy: 0.6189 - loss: 1.3700 - val_accuracy: 0.8834 - val_loss: 0.8235
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 318ms/step - accuracy: 0.6235 - loss: 1.3785 - val_accuracy: 0.8691 - val_loss: 0.8350
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 310ms/step - accuracy: 0.6452 - loss: 1.3295 - val_accuracy: 0.8758 - val_loss: 0.8233
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 314ms/step - accuracy: 0.6318 - loss: 1.3621 - val_accuracy: 0.8796 - val_loss: 0.8213
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 311ms/step - accuracy: 0.6448 - loss: 1.3345 - val_accuracy: 0.8750 - val_loss: 0.8126
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 321ms/step - accuracy: 0.6547 - loss: 1.3237 - val_accuracy: 0.8800 - val_loss: 0.8192
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 315ms/step - accuracy: 0.6545 - loss: 1.3243 - val_accuracy: 0.8838 - val_loss: 0.7982
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 312ms/step - accuracy: 0.6542 - loss: 1.3115 - val_accuracy: 0.8763 - val_loss: 0.8110
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 308ms/step - accuracy: 0.6422 - loss: 1.3347 - val_accuracy: 0.8675 - val_loss: 0.8167
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 316ms/step - accuracy: 0.6547 - loss: 1.3150 - val_accuracy: 0.8796 - val_loss: 0.7941
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 309ms/step - accuracy: 0.6626 - loss: 1.2996 - val_accuracy: 0.8825 - val_loss: 0.7897
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 311ms/step - accuracy: 0.6687 - loss: 1.2881 - val_accuracy: 0.8821 - val_loss: 0.7945
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 309ms/step - accuracy: 0.6633 - loss: 1.2910 - val_accuracy: 0.8729 - val_loss: 0.8186
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 324ms/step - accuracy: 0.6639 - loss: 1.3101 - val_accuracy: 0.8909 - val_loss: 0.7825
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 314ms/step - accuracy: 0.6741 - loss: 1.2685 - val_accuracy: 0.8875 - val_loss: 0.7841
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 315ms/step - accuracy: 0.6767 - loss: 1.2814 - val_accuracy: 0.8905 - val_loss: 0.7757
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 310ms/step - accuracy: 0.6721 - loss: 1.2851 - val_accuracy: 0.8804 - val_loss: 0.7953
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 348ms/step - accuracy: 0.6792 - loss: 1.2808 - val_accuracy: 0.8742 - val_loss: 0.7929
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 312ms/step - accuracy: 0.6946 - loss: 1.2504 - val_accuracy: 0.8846 - val_loss: 0.7900
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 315ms/step - accuracy: 0.6738 - loss: 1.2753 - val_accuracy: 0.8938 - val_loss: 0.7823
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 309ms/step - accuracy: 0.6711 - loss: 1.2585 - val_accuracy: 0.8821 - val_loss: 0.7967
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 317ms/step - accuracy: 0.6817 - loss: 1.2600 - val_accuracy: 0.8901 - val_loss: 0.7789
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 314ms/step - accuracy: 0.6695 - loss: 1.2721 - val_accuracy: 0.8942 - val_loss: 0.7651
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 315ms/step - accuracy: 0.6761 - loss: 1.2649 - val_accuracy: 0.9001 - val_loss: 0.7669
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 312ms/step - accuracy: 0.6780 - loss: 1.2611 - val_accuracy: 0.8842 - val_loss: 0.7968
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 315ms/step - accuracy: 0.6731 - loss: 1.2648 - val_accuracy: 0.8855 - val_loss: 0.7765
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 317ms/step - accuracy: 0.6734 - loss: 1.2596 - val_accuracy: 0.9034 - val_loss: 0.7558
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 311ms/step - accuracy: 0.6757 - loss: 1.2641 - val_accuracy: 0.8934 - val_loss: 0.7730
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 308ms/step - accuracy: 0.6753 - loss: 1.2781 - val_accuracy: 0.8813 - val_loss: 0.7911
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 27s 314ms/step - accuracy: 0.6813 - loss: 1.2689 - val_accuracy: 0.8892 - val_loss: 0.7837
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 306ms/step - accuracy: 0.6770 - loss: 1.2516 - val_accuracy: 0.8913 - val_loss: 0.7776
# Epoch 37/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 308ms/step - accuracy: 0.6891 - loss: 1.2591 - val_accuracy: 0.9018 - val_loss: 0.7587
# Epoch 38/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 309ms/step - accuracy: 0.6837 - loss: 1.2703 - val_accuracy: 0.9022 - val_loss: 0.7638
# Epoch 39/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 313ms/step - accuracy: 0.6762 - loss: 1.2628 - val_accuracy: 0.8809 - val_loss: 0.7855
# Epoch 40/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 307ms/step - accuracy: 0.6773 - loss: 1.2856 - val_accuracy: 0.8754 - val_loss: 0.7924
# Epoch 41/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 308ms/step - accuracy: 0.6814 - loss: 1.2825 - val_accuracy: 0.8992 - val_loss: 0.7585
# Epoch 42/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 26s 307ms/step - accuracy: 0.6871 - loss: 1.2519 - val_accuracy: 0.8942 - val_loss: 0.7613
# Final validation accuracy: 90.34%

# %%
# store information about the run
with open("weights/transfer_learning/"+ run_dir_name + "/hyperparameters.txt", "w") as file:
    file.write(f"Hyperparameters:\n{hyperparameters}\n\n")
    file.write(f"Final validation accuracy: {final_val_accuracy}%\n\n")
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")

# %% [markdown]
# ### Then fine-tune the model

# %%
# Some hyperparameters may be changed or added for fine-tuning

hyperparameters['transfer_learning'] = 'fine_tuning'
hyperparameters['n_layers_frozen'] = 124
# optionally change the learning rate for fine tuning
hyperparameters['lr'] = 1e-4#1e-4

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model(model_filepath, compile=False)


# Compila di nuovo il modello
#ft_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Select trainable layers

# %%
model_custom_layer = "efficientnetv2-m" # CHANGE THIS WITH THE MODEL

# Set the model layers as trainable
ft_model.get_layer(model_custom_layer).trainable = True

# Set all layers as non-trainable
for layer in ft_model.get_layer(model_custom_layer).layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers (THERE COULD BE DIFFERENT CHOICES IN OTHER MODELS)
for i, layer in enumerate(ft_model.get_layer(model_custom_layer).layers):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)
# Out:
# 2 stem_conv Conv2D True
# 5 block1a_project_conv Conv2D True
# 9 block1b_project_conv Conv2D True
# 14 block1c_project_conv Conv2D True
# 19 block2a_expand_conv Conv2D True
# 22 block2a_project_conv Conv2D True
# 24 block2b_expand_conv Conv2D True
# 27 block2b_project_conv Conv2D True
# 31 block2c_expand_conv Conv2D True
# 34 block2c_project_conv Conv2D True
# 38 block2d_expand_conv Conv2D True
# 41 block2d_project_conv Conv2D True
# 45 block2e_expand_conv Conv2D True
# 48 block2e_project_conv Conv2D True
# 52 block3a_expand_conv Conv2D True
# 55 block3a_project_conv Conv2D True
# 57 block3b_expand_conv Conv2D True
# 60 block3b_project_conv Conv2D True
# 64 block3c_expand_conv Conv2D True
# 67 block3c_project_conv Conv2D True
# 71 block3d_expand_conv Conv2D True
# 74 block3d_project_conv Conv2D True
# 78 block3e_expand_conv Conv2D True
# 81 block3e_project_conv Conv2D True
# 85 block4a_expand_conv Conv2D True
# 88 block4a_dwconv2 DepthwiseConv2D True
# 93 block4a_se_reduce Conv2D True
# 94 block4a_se_expand Conv2D True
# 96 block4a_project_conv Conv2D True
# 98 block4b_expand_conv Conv2D True
# 101 block4b_dwconv2 DepthwiseConv2D True
# 106 block4b_se_reduce Conv2D True
# 107 block4b_se_expand Conv2D True
# 109 block4b_project_conv Conv2D True
# 113 block4c_expand_conv Conv2D True
# 116 block4c_dwconv2 DepthwiseConv2D True
# 121 block4c_se_reduce Conv2D True
# 122 block4c_se_expand Conv2D True
# 124 block4c_project_conv Conv2D True
# 128 block4d_expand_conv Conv2D True
# 131 block4d_dwconv2 DepthwiseConv2D True
# 136 block4d_se_reduce Conv2D True
# 137 block4d_se_expand Conv2D True
# 139 block4d_project_conv Conv2D True
# 143 block4e_expand_conv Conv2D True
# 146 block4e_dwconv2 DepthwiseConv2D True
# 151 block4e_se_reduce Conv2D True
# 152 block4e_se_expand Conv2D True
# 154 block4e_project_conv Conv2D True
# 158 block4f_expand_conv Conv2D True
# 161 block4f_dwconv2 DepthwiseConv2D True
# 166 block4f_se_reduce Conv2D True
# 167 block4f_se_expand Conv2D True
# 169 block4f_project_conv Conv2D True
# 173 block4g_expand_conv Conv2D True
# 176 block4g_dwconv2 DepthwiseConv2D True
# 181 block4g_se_reduce Conv2D True
# 182 block4g_se_expand Conv2D True
# 184 block4g_project_conv Conv2D True
# 188 block5a_expand_conv Conv2D True
# 191 block5a_dwconv2 DepthwiseConv2D True
# 196 block5a_se_reduce Conv2D True
# 197 block5a_se_expand Conv2D True
# 199 block5a_project_conv Conv2D True
# 201 block5b_expand_conv Conv2D True
# 204 block5b_dwconv2 DepthwiseConv2D True
# 209 block5b_se_reduce Conv2D True
# 210 block5b_se_expand Conv2D True
# 212 block5b_project_conv Conv2D True
# 216 block5c_expand_conv Conv2D True
# 219 block5c_dwconv2 DepthwiseConv2D True
# 224 block5c_se_reduce Conv2D True
# 225 block5c_se_expand Conv2D True
# 227 block5c_project_conv Conv2D True
# 231 block5d_expand_conv Conv2D True
# 234 block5d_dwconv2 DepthwiseConv2D True
# 239 block5d_se_reduce Conv2D True
# 240 block5d_se_expand Conv2D True
# 242 block5d_project_conv Conv2D True
# 246 block5e_expand_conv Conv2D True
# 249 block5e_dwconv2 DepthwiseConv2D True
# 254 block5e_se_reduce Conv2D True
# 255 block5e_se_expand Conv2D True
# 257 block5e_project_conv Conv2D True
# 261 block5f_expand_conv Conv2D True
# 264 block5f_dwconv2 DepthwiseConv2D True
# 269 block5f_se_reduce Conv2D True
# 270 block5f_se_expand Conv2D True
# 272 block5f_project_conv Conv2D True
# 276 block5g_expand_conv Conv2D True
# 279 block5g_dwconv2 DepthwiseConv2D True
# 284 block5g_se_reduce Conv2D True
# 285 block5g_se_expand Conv2D True
# 287 block5g_project_conv Conv2D True
# 291 block5h_expand_conv Conv2D True
# 294 block5h_dwconv2 DepthwiseConv2D True
# 299 block5h_se_reduce Conv2D True
# 300 block5h_se_expand Conv2D True
# 302 block5h_project_conv Conv2D True
# 306 block5i_expand_conv Conv2D True
# 309 block5i_dwconv2 DepthwiseConv2D True
# 314 block5i_se_reduce Conv2D True
# 315 block5i_se_expand Conv2D True
# 317 block5i_project_conv Conv2D True
# 321 block5j_expand_conv Conv2D True
# 324 block5j_dwconv2 DepthwiseConv2D True
# 329 block5j_se_reduce Conv2D True
# 330 block5j_se_expand Conv2D True
# 332 block5j_project_conv Conv2D True
# 336 block5k_expand_conv Conv2D True
# 339 block5k_dwconv2 DepthwiseConv2D True
# 344 block5k_se_reduce Conv2D True
# 345 block5k_se_expand Conv2D True
# 347 block5k_project_conv Conv2D True
# 351 block5l_expand_conv Conv2D True
# 354 block5l_dwconv2 DepthwiseConv2D True
# 359 block5l_se_reduce Conv2D True
# 360 block5l_se_expand Conv2D True
# 362 block5l_project_conv Conv2D True
# 366 block5m_expand_conv Conv2D True
# 369 block5m_dwconv2 DepthwiseConv2D True
# 374 block5m_se_reduce Conv2D True
# 375 block5m_se_expand Conv2D True
# 377 block5m_project_conv Conv2D True
# 381 block5n_expand_conv Conv2D True
# 384 block5n_dwconv2 DepthwiseConv2D True
# 389 block5n_se_reduce Conv2D True
# 390 block5n_se_expand Conv2D True
# 392 block5n_project_conv Conv2D True
# 396 block6a_expand_conv Conv2D True
# 399 block6a_dwconv2 DepthwiseConv2D True
# 404 block6a_se_reduce Conv2D True
# 405 block6a_se_expand Conv2D True
# 407 block6a_project_conv Conv2D True
# 409 block6b_expand_conv Conv2D True
# 412 block6b_dwconv2 DepthwiseConv2D True
# 417 block6b_se_reduce Conv2D True
# 418 block6b_se_expand Conv2D True
# 420 block6b_project_conv Conv2D True
# 424 block6c_expand_conv Conv2D True
# 427 block6c_dwconv2 DepthwiseConv2D True
# 432 block6c_se_reduce Conv2D True
# 433 block6c_se_expand Conv2D True
# 435 block6c_project_conv Conv2D True
# 439 block6d_expand_conv Conv2D True
# 442 block6d_dwconv2 DepthwiseConv2D True
# 447 block6d_se_reduce Conv2D True
# 448 block6d_se_expand Conv2D True
# 450 block6d_project_conv Conv2D True
# 454 block6e_expand_conv Conv2D True
# 457 block6e_dwconv2 DepthwiseConv2D True
# 462 block6e_se_reduce Conv2D True
# 463 block6e_se_expand Conv2D True
# 465 block6e_project_conv Conv2D True
# 469 block6f_expand_conv Conv2D True
# 472 block6f_dwconv2 DepthwiseConv2D True
# 477 block6f_se_reduce Conv2D True
# 478 block6f_se_expand Conv2D True
# 480 block6f_project_conv Conv2D True
# 484 block6g_expand_conv Conv2D True
# 487 block6g_dwconv2 DepthwiseConv2D True
# 492 block6g_se_reduce Conv2D True
# 493 block6g_se_expand Conv2D True
# 495 block6g_project_conv Conv2D True
# 499 block6h_expand_conv Conv2D True
# 502 block6h_dwconv2 DepthwiseConv2D True
# 507 block6h_se_reduce Conv2D True
# 508 block6h_se_expand Conv2D True
# 510 block6h_project_conv Conv2D True
# 514 block6i_expand_conv Conv2D True
# 517 block6i_dwconv2 DepthwiseConv2D True
# 522 block6i_se_reduce Conv2D True
# 523 block6i_se_expand Conv2D True
# 525 block6i_project_conv Conv2D True
# 529 block6j_expand_conv Conv2D True
# 532 block6j_dwconv2 DepthwiseConv2D True
# 537 block6j_se_reduce Conv2D True
# 538 block6j_se_expand Conv2D True
# 540 block6j_project_conv Conv2D True
# 544 block6k_expand_conv Conv2D True
# 547 block6k_dwconv2 DepthwiseConv2D True
# 552 block6k_se_reduce Conv2D True
# 553 block6k_se_expand Conv2D True
# 555 block6k_project_conv Conv2D True
# 559 block6l_expand_conv Conv2D True
# 562 block6l_dwconv2 DepthwiseConv2D True
# 567 block6l_se_reduce Conv2D True
# 568 block6l_se_expand Conv2D True
# 570 block6l_project_conv Conv2D True
# 574 block6m_expand_conv Conv2D True
# 577 block6m_dwconv2 DepthwiseConv2D True
# 582 block6m_se_reduce Conv2D True
# 583 block6m_se_expand Conv2D True
# 585 block6m_project_conv Conv2D True
# 589 block6n_expand_conv Conv2D True
# 592 block6n_dwconv2 DepthwiseConv2D True
# 597 block6n_se_reduce Conv2D True
# 598 block6n_se_expand Conv2D True
# 600 block6n_project_conv Conv2D True
# 604 block6o_expand_conv Conv2D True
# 607 block6o_dwconv2 DepthwiseConv2D True
# 612 block6o_se_reduce Conv2D True
# 613 block6o_se_expand Conv2D True
# 615 block6o_project_conv Conv2D True
# 619 block6p_expand_conv Conv2D True
# 622 block6p_dwconv2 DepthwiseConv2D True
# 627 block6p_se_reduce Conv2D True
# 628 block6p_se_expand Conv2D True
# 630 block6p_project_conv Conv2D True
# 634 block6q_expand_conv Conv2D True
# 637 block6q_dwconv2 DepthwiseConv2D True
# 642 block6q_se_reduce Conv2D True
# 643 block6q_se_expand Conv2D True
# 645 block6q_project_conv Conv2D True
# 649 block6r_expand_conv Conv2D True
# 652 block6r_dwconv2 DepthwiseConv2D True
# 657 block6r_se_reduce Conv2D True
# 658 block6r_se_expand Conv2D True
# 660 block6r_project_conv Conv2D True
# 664 block7a_expand_conv Conv2D True
# 667 block7a_dwconv2 DepthwiseConv2D True
# 672 block7a_se_reduce Conv2D True
# 673 block7a_se_expand Conv2D True
# 675 block7a_project_conv Conv2D True
# 677 block7b_expand_conv Conv2D True
# 680 block7b_dwconv2 DepthwiseConv2D True
# 685 block7b_se_reduce Conv2D True
# 686 block7b_se_expand Conv2D True
# 688 block7b_project_conv Conv2D True
# 692 block7c_expand_conv Conv2D True
# 695 block7c_dwconv2 DepthwiseConv2D True
# 700 block7c_se_reduce Conv2D True
# 701 block7c_se_expand Conv2D True
# 703 block7c_project_conv Conv2D True
# 707 block7d_expand_conv Conv2D True
# 710 block7d_dwconv2 DepthwiseConv2D True
# 715 block7d_se_reduce Conv2D True
# 716 block7d_se_expand Conv2D True
# 718 block7d_project_conv Conv2D True
# 722 block7e_expand_conv Conv2D True
# 725 block7e_dwconv2 DepthwiseConv2D True
# 730 block7e_se_reduce Conv2D True
# 731 block7e_se_expand Conv2D True
# 733 block7e_project_conv Conv2D True
# 737 top_conv Conv2D True

# %%
# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer(model_custom_layer).layers[:hyperparameters['n_layers_frozen']]):
    layer.trainable = False#prima parte non trainable

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-m').layers):
    print(i, layer.name, layer.trainable)#last part to retrain
# Out:
# 0 input_layer_3 False
# 1 rescaling_3 False
# 2 stem_conv False
# 3 stem_bn False
# 4 stem_activation False
# 5 block1a_project_conv False
# 6 block1a_project_bn False
# 7 block1a_project_activation False
# 8 block1a_add False
# 9 block1b_project_conv False
# 10 block1b_project_bn False
# 11 block1b_project_activation False
# 12 block1b_drop False
# 13 block1b_add False
# 14 block1c_project_conv False
# 15 block1c_project_bn False
# 16 block1c_project_activation False
# 17 block1c_drop False
# 18 block1c_add False
# 19 block2a_expand_conv False
# 20 block2a_expand_bn False
# 21 block2a_expand_activation False
# 22 block2a_project_conv False
# 23 block2a_project_bn False
# 24 block2b_expand_conv False
# 25 block2b_expand_bn False
# 26 block2b_expand_activation False
# 27 block2b_project_conv False
# 28 block2b_project_bn False
# 29 block2b_drop False
# 30 block2b_add False
# 31 block2c_expand_conv False
# 32 block2c_expand_bn False
# 33 block2c_expand_activation False
# 34 block2c_project_conv False
# 35 block2c_project_bn False
# 36 block2c_drop False
# 37 block2c_add False
# 38 block2d_expand_conv False
# 39 block2d_expand_bn False
# 40 block2d_expand_activation False
# 41 block2d_project_conv False
# 42 block2d_project_bn False
# 43 block2d_drop False
# 44 block2d_add False
# 45 block2e_expand_conv False
# 46 block2e_expand_bn False
# 47 block2e_expand_activation False
# 48 block2e_project_conv False
# 49 block2e_project_bn False
# 50 block2e_drop False
# 51 block2e_add False
# 52 block3a_expand_conv False
# 53 block3a_expand_bn False
# 54 block3a_expand_activation False
# 55 block3a_project_conv False
# 56 block3a_project_bn False
# 57 block3b_expand_conv False
# 58 block3b_expand_bn False
# 59 block3b_expand_activation False
# 60 block3b_project_conv False
# 61 block3b_project_bn False
# 62 block3b_drop False
# 63 block3b_add False
# 64 block3c_expand_conv False
# 65 block3c_expand_bn False
# 66 block3c_expand_activation False
# 67 block3c_project_conv False
# 68 block3c_project_bn False
# 69 block3c_drop False
# 70 block3c_add False
# 71 block3d_expand_conv False
# 72 block3d_expand_bn False
# 73 block3d_expand_activation False
# 74 block3d_project_conv False
# 75 block3d_project_bn False
# 76 block3d_drop False
# 77 block3d_add False
# 78 block3e_expand_conv False
# 79 block3e_expand_bn False
# 80 block3e_expand_activation False
# 81 block3e_project_conv False
# 82 block3e_project_bn False
# 83 block3e_drop False
# 84 block3e_add False
# 85 block4a_expand_conv False
# 86 block4a_expand_bn False
# 87 block4a_expand_activation False
# 88 block4a_dwconv2 False
# 89 block4a_bn False
# 90 block4a_activation False
# 91 block4a_se_squeeze False
# 92 block4a_se_reshape False
# 93 block4a_se_reduce False
# 94 block4a_se_expand False
# 95 block4a_se_excite False
# 96 block4a_project_conv False
# 97 block4a_project_bn False
# 98 block4b_expand_conv False
# 99 block4b_expand_bn False
# 100 block4b_expand_activation False
# 101 block4b_dwconv2 False
# 102 block4b_bn False
# 103 block4b_activation False
# 104 block4b_se_squeeze False
# 105 block4b_se_reshape False
# 106 block4b_se_reduce False
# 107 block4b_se_expand False
# 108 block4b_se_excite False
# 109 block4b_project_conv False
# 110 block4b_project_bn False
# 111 block4b_drop False
# 112 block4b_add False
# 113 block4c_expand_conv False
# 114 block4c_expand_bn False
# 115 block4c_expand_activation False
# 116 block4c_dwconv2 False
# 117 block4c_bn False
# 118 block4c_activation False
# 119 block4c_se_squeeze False
# 120 block4c_se_reshape False
# 121 block4c_se_reduce False
# 122 block4c_se_expand False
# 123 block4c_se_excite False
# 124 block4c_project_conv True
# 125 block4c_project_bn False
# 126 block4c_drop False
# 127 block4c_add False
# 128 block4d_expand_conv True
# 129 block4d_expand_bn False
# 130 block4d_expand_activation False
# 131 block4d_dwconv2 True
# 132 block4d_bn False
# 133 block4d_activation False
# 134 block4d_se_squeeze False
# 135 block4d_se_reshape False
# 136 block4d_se_reduce True
# 137 block4d_se_expand True
# 138 block4d_se_excite False
# 139 block4d_project_conv True
# 140 block4d_project_bn False
# 141 block4d_drop False
# 142 block4d_add False
# 143 block4e_expand_conv True
# 144 block4e_expand_bn False
# 145 block4e_expand_activation False
# 146 block4e_dwconv2 True
# 147 block4e_bn False
# 148 block4e_activation False
# 149 block4e_se_squeeze False
# 150 block4e_se_reshape False
# 151 block4e_se_reduce True
# 152 block4e_se_expand True
# 153 block4e_se_excite False
# 154 block4e_project_conv True
# 155 block4e_project_bn False
# 156 block4e_drop False
# 157 block4e_add False
# 158 block4f_expand_conv True
# 159 block4f_expand_bn False
# 160 block4f_expand_activation False
# 161 block4f_dwconv2 True
# 162 block4f_bn False
# 163 block4f_activation False
# 164 block4f_se_squeeze False
# 165 block4f_se_reshape False
# 166 block4f_se_reduce True
# 167 block4f_se_expand True
# 168 block4f_se_excite False
# 169 block4f_project_conv True
# 170 block4f_project_bn False
# 171 block4f_drop False
# 172 block4f_add False
# 173 block4g_expand_conv True
# 174 block4g_expand_bn False
# 175 block4g_expand_activation False
# 176 block4g_dwconv2 True
# 177 block4g_bn False
# 178 block4g_activation False
# 179 block4g_se_squeeze False
# 180 block4g_se_reshape False
# 181 block4g_se_reduce True
# 182 block4g_se_expand True
# 183 block4g_se_excite False
# 184 block4g_project_conv True
# 185 block4g_project_bn False
# 186 block4g_drop False
# 187 block4g_add False
# 188 block5a_expand_conv True
# 189 block5a_expand_bn False
# 190 block5a_expand_activation False
# 191 block5a_dwconv2 True
# 192 block5a_bn False
# 193 block5a_activation False
# 194 block5a_se_squeeze False
# 195 block5a_se_reshape False
# 196 block5a_se_reduce True
# 197 block5a_se_expand True
# 198 block5a_se_excite False
# 199 block5a_project_conv True
# 200 block5a_project_bn False
# 201 block5b_expand_conv True
# 202 block5b_expand_bn False
# 203 block5b_expand_activation False
# 204 block5b_dwconv2 True
# 205 block5b_bn False
# 206 block5b_activation False
# 207 block5b_se_squeeze False
# 208 block5b_se_reshape False
# 209 block5b_se_reduce True
# 210 block5b_se_expand True
# 211 block5b_se_excite False
# 212 block5b_project_conv True
# 213 block5b_project_bn False
# 214 block5b_drop False
# 215 block5b_add False
# 216 block5c_expand_conv True
# 217 block5c_expand_bn False
# 218 block5c_expand_activation False
# 219 block5c_dwconv2 True
# 220 block5c_bn False
# 221 block5c_activation False
# 222 block5c_se_squeeze False
# 223 block5c_se_reshape False
# 224 block5c_se_reduce True
# 225 block5c_se_expand True
# 226 block5c_se_excite False
# 227 block5c_project_conv True
# 228 block5c_project_bn False
# 229 block5c_drop False
# 230 block5c_add False
# 231 block5d_expand_conv True
# 232 block5d_expand_bn False
# 233 block5d_expand_activation False
# 234 block5d_dwconv2 True
# 235 block5d_bn False
# 236 block5d_activation False
# 237 block5d_se_squeeze False
# 238 block5d_se_reshape False
# 239 block5d_se_reduce True
# 240 block5d_se_expand True
# 241 block5d_se_excite False
# 242 block5d_project_conv True
# 243 block5d_project_bn False
# 244 block5d_drop False
# 245 block5d_add False
# 246 block5e_expand_conv True
# 247 block5e_expand_bn False
# 248 block5e_expand_activation False
# 249 block5e_dwconv2 True
# 250 block5e_bn False
# 251 block5e_activation False
# 252 block5e_se_squeeze False
# 253 block5e_se_reshape False
# 254 block5e_se_reduce True
# 255 block5e_se_expand True
# 256 block5e_se_excite False
# 257 block5e_project_conv True
# 258 block5e_project_bn False
# 259 block5e_drop False
# 260 block5e_add False
# 261 block5f_expand_conv True
# 262 block5f_expand_bn False
# 263 block5f_expand_activation False
# 264 block5f_dwconv2 True
# 265 block5f_bn False
# 266 block5f_activation False
# 267 block5f_se_squeeze False
# 268 block5f_se_reshape False
# 269 block5f_se_reduce True
# 270 block5f_se_expand True
# 271 block5f_se_excite False
# 272 block5f_project_conv True
# 273 block5f_project_bn False
# 274 block5f_drop False
# 275 block5f_add False
# 276 block5g_expand_conv True
# 277 block5g_expand_bn False
# 278 block5g_expand_activation False
# 279 block5g_dwconv2 True
# 280 block5g_bn False
# 281 block5g_activation False
# 282 block5g_se_squeeze False
# 283 block5g_se_reshape False
# 284 block5g_se_reduce True
# 285 block5g_se_expand True
# 286 block5g_se_excite False
# 287 block5g_project_conv True
# 288 block5g_project_bn False
# 289 block5g_drop False
# 290 block5g_add False
# 291 block5h_expand_conv True
# 292 block5h_expand_bn False
# 293 block5h_expand_activation False
# 294 block5h_dwconv2 True
# 295 block5h_bn False
# 296 block5h_activation False
# 297 block5h_se_squeeze False
# 298 block5h_se_reshape False
# 299 block5h_se_reduce True
# 300 block5h_se_expand True
# 301 block5h_se_excite False
# 302 block5h_project_conv True
# 303 block5h_project_bn False
# 304 block5h_drop False
# 305 block5h_add False
# 306 block5i_expand_conv True
# 307 block5i_expand_bn False
# 308 block5i_expand_activation False
# 309 block5i_dwconv2 True
# 310 block5i_bn False
# 311 block5i_activation False
# 312 block5i_se_squeeze False
# 313 block5i_se_reshape False
# 314 block5i_se_reduce True
# 315 block5i_se_expand True
# 316 block5i_se_excite False
# 317 block5i_project_conv True
# 318 block5i_project_bn False
# 319 block5i_drop False
# 320 block5i_add False
# 321 block5j_expand_conv True
# 322 block5j_expand_bn False
# 323 block5j_expand_activation False
# 324 block5j_dwconv2 True
# 325 block5j_bn False
# 326 block5j_activation False
# 327 block5j_se_squeeze False
# 328 block5j_se_reshape False
# 329 block5j_se_reduce True
# 330 block5j_se_expand True
# 331 block5j_se_excite False
# 332 block5j_project_conv True
# 333 block5j_project_bn False
# 334 block5j_drop False
# 335 block5j_add False
# 336 block5k_expand_conv True
# 337 block5k_expand_bn False
# 338 block5k_expand_activation False
# 339 block5k_dwconv2 True
# 340 block5k_bn False
# 341 block5k_activation False
# 342 block5k_se_squeeze False
# 343 block5k_se_reshape False
# 344 block5k_se_reduce True
# 345 block5k_se_expand True
# 346 block5k_se_excite False
# 347 block5k_project_conv True
# 348 block5k_project_bn False
# 349 block5k_drop False
# 350 block5k_add False
# 351 block5l_expand_conv True
# 352 block5l_expand_bn False
# 353 block5l_expand_activation False
# 354 block5l_dwconv2 True
# 355 block5l_bn False
# 356 block5l_activation False
# 357 block5l_se_squeeze False
# 358 block5l_se_reshape False
# 359 block5l_se_reduce True
# 360 block5l_se_expand True
# 361 block5l_se_excite False
# 362 block5l_project_conv True
# 363 block5l_project_bn False
# 364 block5l_drop False
# 365 block5l_add False
# 366 block5m_expand_conv True
# 367 block5m_expand_bn False
# 368 block5m_expand_activation False
# 369 block5m_dwconv2 True
# 370 block5m_bn False
# 371 block5m_activation False
# 372 block5m_se_squeeze False
# 373 block5m_se_reshape False
# 374 block5m_se_reduce True
# 375 block5m_se_expand True
# 376 block5m_se_excite False
# 377 block5m_project_conv True
# 378 block5m_project_bn False
# 379 block5m_drop False
# 380 block5m_add False
# 381 block5n_expand_conv True
# 382 block5n_expand_bn False
# 383 block5n_expand_activation False
# 384 block5n_dwconv2 True
# 385 block5n_bn False
# 386 block5n_activation False
# 387 block5n_se_squeeze False
# 388 block5n_se_reshape False
# 389 block5n_se_reduce True
# 390 block5n_se_expand True
# 391 block5n_se_excite False
# 392 block5n_project_conv True
# 393 block5n_project_bn False
# 394 block5n_drop False
# 395 block5n_add False
# 396 block6a_expand_conv True
# 397 block6a_expand_bn False
# 398 block6a_expand_activation False
# 399 block6a_dwconv2 True
# 400 block6a_bn False
# 401 block6a_activation False
# 402 block6a_se_squeeze False
# 403 block6a_se_reshape False
# 404 block6a_se_reduce True
# 405 block6a_se_expand True
# 406 block6a_se_excite False
# 407 block6a_project_conv True
# 408 block6a_project_bn False
# 409 block6b_expand_conv True
# 410 block6b_expand_bn False
# 411 block6b_expand_activation False
# 412 block6b_dwconv2 True
# 413 block6b_bn False
# 414 block6b_activation False
# 415 block6b_se_squeeze False
# 416 block6b_se_reshape False
# 417 block6b_se_reduce True
# 418 block6b_se_expand True
# 419 block6b_se_excite False
# 420 block6b_project_conv True
# 421 block6b_project_bn False
# 422 block6b_drop False
# 423 block6b_add False
# 424 block6c_expand_conv True
# 425 block6c_expand_bn False
# 426 block6c_expand_activation False
# 427 block6c_dwconv2 True
# 428 block6c_bn False
# 429 block6c_activation False
# 430 block6c_se_squeeze False
# 431 block6c_se_reshape False
# 432 block6c_se_reduce True
# 433 block6c_se_expand True
# 434 block6c_se_excite False
# 435 block6c_project_conv True
# 436 block6c_project_bn False
# 437 block6c_drop False
# 438 block6c_add False
# 439 block6d_expand_conv True
# 440 block6d_expand_bn False
# 441 block6d_expand_activation False
# 442 block6d_dwconv2 True
# 443 block6d_bn False
# 444 block6d_activation False
# 445 block6d_se_squeeze False
# 446 block6d_se_reshape False
# 447 block6d_se_reduce True
# 448 block6d_se_expand True
# 449 block6d_se_excite False
# 450 block6d_project_conv True
# 451 block6d_project_bn False
# 452 block6d_drop False
# 453 block6d_add False
# 454 block6e_expand_conv True
# 455 block6e_expand_bn False
# 456 block6e_expand_activation False
# 457 block6e_dwconv2 True
# 458 block6e_bn False
# 459 block6e_activation False
# 460 block6e_se_squeeze False
# 461 block6e_se_reshape False
# 462 block6e_se_reduce True
# 463 block6e_se_expand True
# 464 block6e_se_excite False
# 465 block6e_project_conv True
# 466 block6e_project_bn False
# 467 block6e_drop False
# 468 block6e_add False
# 469 block6f_expand_conv True
# 470 block6f_expand_bn False
# 471 block6f_expand_activation False
# 472 block6f_dwconv2 True
# 473 block6f_bn False
# 474 block6f_activation False
# 475 block6f_se_squeeze False
# 476 block6f_se_reshape False
# 477 block6f_se_reduce True
# 478 block6f_se_expand True
# 479 block6f_se_excite False
# 480 block6f_project_conv True
# 481 block6f_project_bn False
# 482 block6f_drop False
# 483 block6f_add False
# 484 block6g_expand_conv True
# 485 block6g_expand_bn False
# 486 block6g_expand_activation False
# 487 block6g_dwconv2 True
# 488 block6g_bn False
# 489 block6g_activation False
# 490 block6g_se_squeeze False
# 491 block6g_se_reshape False
# 492 block6g_se_reduce True
# 493 block6g_se_expand True
# 494 block6g_se_excite False
# 495 block6g_project_conv True
# 496 block6g_project_bn False
# 497 block6g_drop False
# 498 block6g_add False
# 499 block6h_expand_conv True
# 500 block6h_expand_bn False
# 501 block6h_expand_activation False
# 502 block6h_dwconv2 True
# 503 block6h_bn False
# 504 block6h_activation False
# 505 block6h_se_squeeze False
# 506 block6h_se_reshape False
# 507 block6h_se_reduce True
# 508 block6h_se_expand True
# 509 block6h_se_excite False
# 510 block6h_project_conv True
# 511 block6h_project_bn False
# 512 block6h_drop False
# 513 block6h_add False
# 514 block6i_expand_conv True
# 515 block6i_expand_bn False
# 516 block6i_expand_activation False
# 517 block6i_dwconv2 True
# 518 block6i_bn False
# 519 block6i_activation False
# 520 block6i_se_squeeze False
# 521 block6i_se_reshape False
# 522 block6i_se_reduce True
# 523 block6i_se_expand True
# 524 block6i_se_excite False
# 525 block6i_project_conv True
# 526 block6i_project_bn False
# 527 block6i_drop False
# 528 block6i_add False
# 529 block6j_expand_conv True
# 530 block6j_expand_bn False
# 531 block6j_expand_activation False
# 532 block6j_dwconv2 True
# 533 block6j_bn False
# 534 block6j_activation False
# 535 block6j_se_squeeze False
# 536 block6j_se_reshape False
# 537 block6j_se_reduce True
# 538 block6j_se_expand True
# 539 block6j_se_excite False
# 540 block6j_project_conv True
# 541 block6j_project_bn False
# 542 block6j_drop False
# 543 block6j_add False
# 544 block6k_expand_conv True
# 545 block6k_expand_bn False
# 546 block6k_expand_activation False
# 547 block6k_dwconv2 True
# 548 block6k_bn False
# 549 block6k_activation False
# 550 block6k_se_squeeze False
# 551 block6k_se_reshape False
# 552 block6k_se_reduce True
# 553 block6k_se_expand True
# 554 block6k_se_excite False
# 555 block6k_project_conv True
# 556 block6k_project_bn False
# 557 block6k_drop False
# 558 block6k_add False
# 559 block6l_expand_conv True
# 560 block6l_expand_bn False
# 561 block6l_expand_activation False
# 562 block6l_dwconv2 True
# 563 block6l_bn False
# 564 block6l_activation False
# 565 block6l_se_squeeze False
# 566 block6l_se_reshape False
# 567 block6l_se_reduce True
# 568 block6l_se_expand True
# 569 block6l_se_excite False
# 570 block6l_project_conv True
# 571 block6l_project_bn False
# 572 block6l_drop False
# 573 block6l_add False
# 574 block6m_expand_conv True
# 575 block6m_expand_bn False
# 576 block6m_expand_activation False
# 577 block6m_dwconv2 True
# 578 block6m_bn False
# 579 block6m_activation False
# 580 block6m_se_squeeze False
# 581 block6m_se_reshape False
# 582 block6m_se_reduce True
# 583 block6m_se_expand True
# 584 block6m_se_excite False
# 585 block6m_project_conv True
# 586 block6m_project_bn False
# 587 block6m_drop False
# 588 block6m_add False
# 589 block6n_expand_conv True
# 590 block6n_expand_bn False
# 591 block6n_expand_activation False
# 592 block6n_dwconv2 True
# 593 block6n_bn False
# 594 block6n_activation False
# 595 block6n_se_squeeze False
# 596 block6n_se_reshape False
# 597 block6n_se_reduce True
# 598 block6n_se_expand True
# 599 block6n_se_excite False
# 600 block6n_project_conv True
# 601 block6n_project_bn False
# 602 block6n_drop False
# 603 block6n_add False
# 604 block6o_expand_conv True
# 605 block6o_expand_bn False
# 606 block6o_expand_activation False
# 607 block6o_dwconv2 True
# 608 block6o_bn False
# 609 block6o_activation False
# 610 block6o_se_squeeze False
# 611 block6o_se_reshape False
# 612 block6o_se_reduce True
# 613 block6o_se_expand True
# 614 block6o_se_excite False
# 615 block6o_project_conv True
# 616 block6o_project_bn False
# 617 block6o_drop False
# 618 block6o_add False
# 619 block6p_expand_conv True
# 620 block6p_expand_bn False
# 621 block6p_expand_activation False
# 622 block6p_dwconv2 True
# 623 block6p_bn False
# 624 block6p_activation False
# 625 block6p_se_squeeze False
# 626 block6p_se_reshape False
# 627 block6p_se_reduce True
# 628 block6p_se_expand True
# 629 block6p_se_excite False
# 630 block6p_project_conv True
# 631 block6p_project_bn False
# 632 block6p_drop False
# 633 block6p_add False
# 634 block6q_expand_conv True
# 635 block6q_expand_bn False
# 636 block6q_expand_activation False
# 637 block6q_dwconv2 True
# 638 block6q_bn False
# 639 block6q_activation False
# 640 block6q_se_squeeze False
# 641 block6q_se_reshape False
# 642 block6q_se_reduce True
# 643 block6q_se_expand True
# 644 block6q_se_excite False
# 645 block6q_project_conv True
# 646 block6q_project_bn False
# 647 block6q_drop False
# 648 block6q_add False
# 649 block6r_expand_conv True
# 650 block6r_expand_bn False
# 651 block6r_expand_activation False
# 652 block6r_dwconv2 True
# 653 block6r_bn False
# 654 block6r_activation False
# 655 block6r_se_squeeze False
# 656 block6r_se_reshape False
# 657 block6r_se_reduce True
# 658 block6r_se_expand True
# 659 block6r_se_excite False
# 660 block6r_project_conv True
# 661 block6r_project_bn False
# 662 block6r_drop False
# 663 block6r_add False
# 664 block7a_expand_conv True
# 665 block7a_expand_bn False
# 666 block7a_expand_activation False
# 667 block7a_dwconv2 True
# 668 block7a_bn False
# 669 block7a_activation False
# 670 block7a_se_squeeze False
# 671 block7a_se_reshape False
# 672 block7a_se_reduce True
# 673 block7a_se_expand True
# 674 block7a_se_excite False
# 675 block7a_project_conv True
# 676 block7a_project_bn False
# 677 block7b_expand_conv True
# 678 block7b_expand_bn False
# 679 block7b_expand_activation False
# 680 block7b_dwconv2 True
# 681 block7b_bn False
# 682 block7b_activation False
# 683 block7b_se_squeeze False
# 684 block7b_se_reshape False
# 685 block7b_se_reduce True
# 686 block7b_se_expand True
# 687 block7b_se_excite False
# 688 block7b_project_conv True
# 689 block7b_project_bn False
# 690 block7b_drop False
# 691 block7b_add False
# 692 block7c_expand_conv True
# 693 block7c_expand_bn False
# 694 block7c_expand_activation False
# 695 block7c_dwconv2 True
# 696 block7c_bn False
# 697 block7c_activation False
# 698 block7c_se_squeeze False
# 699 block7c_se_reshape False
# 700 block7c_se_reduce True
# 701 block7c_se_expand True
# 702 block7c_se_excite False
# 703 block7c_project_conv True
# 704 block7c_project_bn False
# 705 block7c_drop False
# 706 block7c_add False
# 707 block7d_expand_conv True
# 708 block7d_expand_bn False
# 709 block7d_expand_activation False
# 710 block7d_dwconv2 True
# 711 block7d_bn False
# 712 block7d_activation False
# 713 block7d_se_squeeze False
# 714 block7d_se_reshape False
# 715 block7d_se_reduce True
# 716 block7d_se_expand True
# 717 block7d_se_excite False
# 718 block7d_project_conv True
# 719 block7d_project_bn False
# 720 block7d_drop False
# 721 block7d_add False
# 722 block7e_expand_conv True
# 723 block7e_expand_bn False
# 724 block7e_expand_activation False
# 725 block7e_dwconv2 True
# 726 block7e_bn False
# 727 block7e_activation False
# 728 block7e_se_squeeze False
# 729 block7e_se_reshape False
# 730 block7e_se_reduce True
# 731 block7e_se_expand True
# 732 block7e_se_excite False
# 733 block7e_project_conv True
# 734 block7e_project_bn False
# 735 block7e_drop False
# 736 block7e_add False
# 737 top_conv True
# 738 top_bn False
# 739 top_activation False
# 740 avg_pool False

# %%
"""
# Cambia epsilon solo nei livelli sbloccati
for layer in ft_model.get_layer(model_custom_layer).layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization) and layer.trainable:
        layer.epsilon = 1e-3  # Aumenta epsilon solo nei BatchNorm attivi
"""
# Out:
# '\n# Cambia epsilon solo nei livelli sbloccati\nfor layer in ft_model.get_layer(model_custom_layer).layers:\n    if isinstance(layer, tf.keras.layers.BatchNormalization) and layer.trainable:\n        layer.epsilon = 1e-3  # Aumenta epsilon solo nei BatchNorm attivi\n'

# %%
# Compile the model
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(label_smoothing=hyperparameters['label_smoothing']), optimizer=tfk.optimizers.Adam(hyperparameters["lr"], weight_decay=hyperparameters["weight_decay"]), metrics=['accuracy'])

# %% [markdown]
# training

# %%
# Fine-tune the model
ft_history = ft_model.fit(
    train_ds_rand,
    batch_size=(hyperparameters['batch_size'] if not hyperparameters['mixup'] else None),
    epochs=hyperparameters['epochs'],
    validation_data=val_ds,
    class_weight=(class_weights if hyperparameters['weighted_loss'] else None),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=hyperparameters['patience'], restore_best_weights=True)]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
run_dir_name = MODEL_NAME + str(final_val_accuracy) + "__" + time().strftime("_%Y-%m-%d_%H.%M")
model_filename = 'weights.keras'
os.makedirs("weights/"+ run_dir_name, exist_ok=True)
ft_model_filepath = "weights/"+ run_dir_name + "/" + model_filename
ft_model.save(ft_model_filepath)

# Delete the model to free up resources
#del ft_model
# Out:
# Epoch 1/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.7111 - loss: 1.1884 - val_accuracy: 0.9327 - val_loss: 0.7420
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 506ms/step - accuracy: 0.7865 - loss: 1.0506 - val_accuracy: 0.9373 - val_loss: 0.6985
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.8218 - loss: 1.0081 - val_accuracy: 0.9423 - val_loss: 0.6760
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 500ms/step - accuracy: 0.8407 - loss: 0.9465 - val_accuracy: 0.9561 - val_loss: 0.6345
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.8504 - loss: 0.9372 - val_accuracy: 0.9615 - val_loss: 0.6219
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 502ms/step - accuracy: 0.8660 - loss: 0.9092 - val_accuracy: 0.9686 - val_loss: 0.5994
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.8733 - loss: 0.8913 - val_accuracy: 0.9661 - val_loss: 0.5945
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.8722 - loss: 0.8888 - val_accuracy: 0.9640 - val_loss: 0.5945
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 504ms/step - accuracy: 0.8852 - loss: 0.8589 - val_accuracy: 0.9712 - val_loss: 0.5739
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.8856 - loss: 0.8656 - val_accuracy: 0.9674 - val_loss: 0.5787
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.8842 - loss: 0.8485 - val_accuracy: 0.9666 - val_loss: 0.5711
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.8987 - loss: 0.8254 - val_accuracy: 0.9594 - val_loss: 0.5785
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.8965 - loss: 0.8257 - val_accuracy: 0.9783 - val_loss: 0.5502
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 498ms/step - accuracy: 0.8997 - loss: 0.8282 - val_accuracy: 0.9758 - val_loss: 0.5462
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.8986 - loss: 0.8239 - val_accuracy: 0.9728 - val_loss: 0.5555
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 499ms/step - accuracy: 0.9018 - loss: 0.8112 - val_accuracy: 0.9816 - val_loss: 0.5366
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9090 - loss: 0.7967 - val_accuracy: 0.9745 - val_loss: 0.5473
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 499ms/step - accuracy: 0.9063 - loss: 0.8044 - val_accuracy: 0.9728 - val_loss: 0.5442
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9160 - loss: 0.8023 - val_accuracy: 0.9799 - val_loss: 0.5297
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 500ms/step - accuracy: 0.9115 - loss: 0.7878 - val_accuracy: 0.9824 - val_loss: 0.5248
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9159 - loss: 0.7926 - val_accuracy: 0.9845 - val_loss: 0.5212
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 499ms/step - accuracy: 0.9139 - loss: 0.7782 - val_accuracy: 0.9770 - val_loss: 0.5299
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9204 - loss: 0.7842 - val_accuracy: 0.9804 - val_loss: 0.5310
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9205 - loss: 0.7710 - val_accuracy: 0.9837 - val_loss: 0.5230
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9202 - loss: 0.7713 - val_accuracy: 0.9845 - val_loss: 0.5161
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.9340 - loss: 0.7439 - val_accuracy: 0.9766 - val_loss: 0.5262
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 492ms/step - accuracy: 0.9196 - loss: 0.7707 - val_accuracy: 0.9833 - val_loss: 0.5168
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9181 - loss: 0.7703 - val_accuracy: 0.9820 - val_loss: 0.5192
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.9195 - loss: 0.7710 - val_accuracy: 0.9862 - val_loss: 0.5137
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 498ms/step - accuracy: 0.9237 - loss: 0.7555 - val_accuracy: 0.9858 - val_loss: 0.5129
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9280 - loss: 0.7689 - val_accuracy: 0.9849 - val_loss: 0.5098
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9302 - loss: 0.7543 - val_accuracy: 0.9862 - val_loss: 0.5080
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - accuracy: 0.9295 - loss: 0.7539 - val_accuracy: 0.9833 - val_loss: 0.5121
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9296 - loss: 0.7437 - val_accuracy: 0.9829 - val_loss: 0.5159
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 491ms/step - accuracy: 0.9313 - loss: 0.7468 - val_accuracy: 0.9845 - val_loss: 0.5149
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - accuracy: 0.9336 - loss: 0.7452 - val_accuracy: 0.9849 - val_loss: 0.5105
# Epoch 37/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 491ms/step - accuracy: 0.9358 - loss: 0.7396 - val_accuracy: 0.9833 - val_loss: 0.5136
# Epoch 38/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 501ms/step - accuracy: 0.9368 - loss: 0.7403 - val_accuracy: 0.9870 - val_loss: 0.5034
# Epoch 39/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9335 - loss: 0.7421 - val_accuracy: 0.9854 - val_loss: 0.5104
# Epoch 40/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9324 - loss: 0.7443 - val_accuracy: 0.9870 - val_loss: 0.5013
# Epoch 41/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9255 - loss: 0.7528 - val_accuracy: 0.9862 - val_loss: 0.5092
# Epoch 42/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9360 - loss: 0.7190 - val_accuracy: 0.9854 - val_loss: 0.5090
# Epoch 43/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9300 - loss: 0.7336 - val_accuracy: 0.9870 - val_loss: 0.5076
# Epoch 44/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9359 - loss: 0.7358 - val_accuracy: 0.9854 - val_loss: 0.5030
# Epoch 45/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9357 - loss: 0.7393 - val_accuracy: 0.9862 - val_loss: 0.5025
# Epoch 46/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9401 - loss: 0.7290 - val_accuracy: 0.9879 - val_loss: 0.4995
# Epoch 47/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9358 - loss: 0.7233 - val_accuracy: 0.9879 - val_loss: 0.4976
# Epoch 48/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9374 - loss: 0.7242 - val_accuracy: 0.9858 - val_loss: 0.5041
# Epoch 49/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 497ms/step - accuracy: 0.9416 - loss: 0.7216 - val_accuracy: 0.9854 - val_loss: 0.5066
# Epoch 50/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9416 - loss: 0.7332 - val_accuracy: 0.9854 - val_loss: 0.5041
# Epoch 51/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9369 - loss: 0.7194 - val_accuracy: 0.9879 - val_loss: 0.5024
# Epoch 52/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9397 - loss: 0.7214 - val_accuracy: 0.9875 - val_loss: 0.5027
# Epoch 53/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 508ms/step - accuracy: 0.9442 - loss: 0.7217 - val_accuracy: 0.9887 - val_loss: 0.4981
# Epoch 54/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 41s 499ms/step - accuracy: 0.9458 - loss: 0.7176 - val_accuracy: 0.9904 - val_loss: 0.4977
# Epoch 55/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - accuracy: 0.9414 - loss: 0.7179 - val_accuracy: 0.9875 - val_loss: 0.4986
# Epoch 56/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9423 - loss: 0.7144 - val_accuracy: 0.9870 - val_loss: 0.5039
# Epoch 57/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9424 - loss: 0.7166 - val_accuracy: 0.9858 - val_loss: 0.5034
# Epoch 58/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 496ms/step - accuracy: 0.9416 - loss: 0.7304 - val_accuracy: 0.9883 - val_loss: 0.4979
# Epoch 59/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 499ms/step - accuracy: 0.9407 - loss: 0.7143 - val_accuracy: 0.9887 - val_loss: 0.5008
# Epoch 60/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9431 - loss: 0.7175 - val_accuracy: 0.9845 - val_loss: 0.5033
# Epoch 61/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - accuracy: 0.9381 - loss: 0.7348 - val_accuracy: 0.9891 - val_loss: 0.4977
# Epoch 62/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 490ms/step - accuracy: 0.9481 - loss: 0.7063 - val_accuracy: 0.9879 - val_loss: 0.4972
# Epoch 63/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 492ms/step - accuracy: 0.9501 - loss: 0.7132 - val_accuracy: 0.9875 - val_loss: 0.4978
# Epoch 64/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9454 - loss: 0.7120 - val_accuracy: 0.9870 - val_loss: 0.4993
# Final validation accuracy: 99.04%

# %% [markdown]
# ## Visualize training

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')
ax2.set_ylim([min(tl_history['val_accuracy']) * 0.95, max(ft_history['val_accuracy']) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize results

# %%
# Load the fine-tuned MobileNetV2 model for prediction on external images
ft_bn_model = tfk.models.load_model(ft_model_filepath, compile=False)

# Compila di nuovo il modello
ft_bn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
# Predict class probabilities and get predicted classes
test_predictions = ft_bn_model.predict(X_val, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)

# Extract ground truth classes
test_gt = np.argmax(y_val, axis=-1)

# Calculate and display validation set accuracy
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy score over the validation set: {round(test_accuracy, 4)}')

# Calculate and display validation set precision
test_precision = precision_score(test_gt, test_predictions, average='weighted')
print(f'Precision score over the validation set: {round(test_precision, 4)}')

# Calculate and display validation set recall
test_recall = recall_score(test_gt, test_predictions, average='weighted')
print(f'Recall score over the validation set: {round(test_recall, 4)}')

# Calculate and display validation set F1 score
test_f1 = f1_score(test_gt, test_predictions, average='weighted')
print(f'F1 score over the validation set: {round(test_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(test_gt, test_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['0','1','2','3','4','5','6','7'], yticklabels=['0','1','2','3','4','5','6','7'], cmap='Blues')
plt.xlabel('True Labels')
plt.ylabel('Predict')
plt.show()
# Out:
# Accuracy score over the validation set: 0.9904
# Precision score over the validation set: 0.9905
# Recall score over the validation set: 0.9904
# F1 score over the validation set: 0.9904

# %% [markdown]
# ### Finally store comments and hyperparameters

# %%
RUN_COMMENTS = "additional considerations..."
# Save the hyperparameters and results to a file
with open("weights/"+ run_dir_name + "/hyperparameters.txt", "w") as file:
    file.write(f"Hyperparameters:\n{hyperparameters}\n\n")
    file.write(f"Final validation accuracy: {final_val_accuracy}%\n\n")
    file.write(f"Comments: {RUN_COMMENTS}\n\n")
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")
# write description and comments in a separate file as well
with open("weights/"+ run_dir_name + "/description.txt", "w") as file:
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")
    file.write(f"Comments: {RUN_COMMENTS}\n\n")
